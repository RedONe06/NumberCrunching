# %% [markdown]
# <a href="https://colab.research.google.com/github/RedONe06/NumberCrunching/blob/main/CalculoNumerico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Cálculo Numérico**

# %% [markdown]
# Bibliotecas que podem ser úteis:
#
#
# *   Numpy: manipulação de matrizes e vetores -> Operações em Algebra Linear
# * SciPy: integração numérica, interpolação, otimização, processamento de sinais e resolução de equações diferenciais
# * Matplotlib: gráficos em 2D e 3D, com sintaxe semelhante à plob do MATLAB
# * SymPy: matemática simbólica

# %% [markdown]
# ---

# %% [markdown]
# # [**Cap. 2 - Representação de números e aritmética de máquina**](https://www.ufrgs.br/reamat/CalculoNumerico/livro-py/rdneadm.html)

# %%
from __future__ import division # Garante divisão de números inteiros em double
import numpy as np # lib de computação científica

# %% [markdown]
# $$
# x = (1001, 101)_2 \\
# = 1*2^3 + 0*2^2 + 0*2^1 + 1*2^0 + 1*2^{-1}
# $$

# %% [markdown]
# # Python Rulebook

# %% [markdown]
# **Naming Conventions**
#
# * Variables, functions: lower_case_with_underscores
# * Classes: CapWords
# * Constants: ALL_CAPS_WITH_UNDERSCORES
# * Private members: prefix with _ (single underscore).
#
# Method:
#
# ``` python
# def greet(name: str) -> str:
#     return f"Hello, {name}"
# ```
